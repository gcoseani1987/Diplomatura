# %%
pip install feedparser
# Out:
# ...
#      |████████████████████████████████| 81kB 3.5MB/s
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-cp36-none-any.whl size=6067 sha256=c387ee8f9c78948d87c9a00035fde182924aea64243595331b1eae193cba9dd5
#   Stored in directory: /root/.cache/pip/wheels/f1/80/5a/444ba08a550cdd241bd9baf8bae44be750efe370adb944506a
# Successfully built sgmllib3k
# ...

# %%
pip install python-slugify

# %%
import bs4
import feedparser
from slugify import slugify
import os

# %%
datos = feedparser.parse('https://www.lavoz.com.ar/rss/tecnologia.xml')  
datos['feed'] ['title']
# Out:
# 'LaVoz.com.ar | Tecnología'

# %%
for item in datos['entries']:
    print("-", item['title'])
# Out:
# - Google integra Meet con su pizarra digital Jamboard para el trabajo y las clases en remoto
# - Instagram dejará cambiar el ícono de la app con motivo de su décimo aniversario
# - Insólito: un televisor viejo, el culpable de que un pueblo entero sufriera cortes de banda ancha por 18 meses
# - Para TikTok, hubo un ataque coordinado para poner el video del suicidio
# - Google amplía las opciones de exportación de Fotos con la selección de álbumes individuales
# - TikTok eliminó más de 100 millones de videos por infringir sus normas durante el primer semestre de 2020
# - La realidad aumentada llega a las sorpresas de los huevos Kinder
# - WhatsApp trabaja en una nueva función de envío de imágenes, videos y GIFs que se autodestruyen
# - Facebook crea una nueva herramienta para reclamar la autoría de imágenes
# - Una lente plana hace fotos de 180 grados en una sola toma
# - Twitter realizará "más análisis" para evitar el sesgo racial en el algoritmo que prioriza las fotos de los tuits
# ...
