# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'input\wtageinf.csv')

# %%
df.shape
# Out:
# (76, 14)

# %%
df.head()
# Out:
#    Sex  Agemos         L         M         S        P3        P5       P10  \
# 0    1     0.0  1.815151  3.530203  0.152385  2.355451  2.526904  2.773802
# 1    1     0.5  1.547523  4.003106  0.146025  2.799549  2.964656  3.209510
# 2    1     1.5  1.068796  4.879525  0.136479  3.614688  3.774849  4.020561
# 3    1     2.5  0.695974  5.672889  0.129678  4.342341  4.503255  4.754479
# 4    1     3.5  0.419815  6.391392  0.124717  4.992898  5.157412  5.416803
#
#         P25       P50       P75       P90       P95       P97
# 0  3.150611  3.530203  3.879077  4.172493  4.340293  4.446488
# 1  3.597396  4.003106  4.387423  4.718161  4.910130  5.032625
# 2  4.428873  4.879525  5.327328  5.728153  5.967102  6.121929
# 3  5.183378  5.672889  6.175598  6.638979  6.921119  7.106250
# 4  5.866806  6.391392  6.942217  7.460702  7.781401  7.993878

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sex     76 non-null     int64
#  1   Agemos  76 non-null     float64
#  2   L       76 non-null     float64
#  3   M       76 non-null     float64
#  4   S       76 non-null     float64
#  5   P3      76 non-null     float64
#  6   P5      76 non-null     float64
#  7   P10     76 non-null     float64
#  8   P25     76 non-null     float64
#  9   P50     76 non-null     float64
#  10  P75     76 non-null     float64
#  11  P90     76 non-null     float64
#  12  P95     76 non-null     float64
#  13  P97     76 non-null     float64
# dtypes: float64(13), int64(1)
# memory usage: 8.4 KB

# %%
df['Sex'].value_counts()
# Out:
# 2    38
# 1    38
# Name: Sex, dtype: int64

# %%
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P3, linestyle='solid', color='black')
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P5, linestyle='dashed', color='black' )
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P10,linestyle='dashdot', color='black')
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P25,linestyle='dotted', color='black')
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P50, color='black')
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P75,linestyle='dotted', color='black')
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P90,linestyle='dashdot', color='black')
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P95,linestyle='dashed', color='black')
plt.plot(df[df['Sex']==1].Agemos, df[df['Sex']==1].P97,linestyle='solid', color='black')

# %%
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P3, linestyle='solid', color='black')
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P5, linestyle='dashed', color='black' )
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P10,linestyle='dashdot', color='black')
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P25,linestyle='dotted', color='black')
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P50, color='black')
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P75,linestyle='dotted', color='black')
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P90,linestyle='dashdot', color='black')
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P95,linestyle='dashed', color='black')
plt.plot(df[df['Sex']==2].Agemos, df[df['Sex']==2].P97,linestyle='solid', color='black')
